# %% [markdown]
# ## Search Youtube for Jose Mourinho Videos

# %% [markdown]
# The purpose of this notebook is to use selenium to get the youtube ids of videos that contain Jose Mourinho press conferences of interviews

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

import os
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver


driver = webdriver.Chrome(chromedriver)
#Change this line to change the youtube query
driver.get("https://www.youtube.com/results?search_query=jose+mourinho+interview")

# %% [markdown]
# ## Get Videos with search "Jose Mourinho Interview"

# %%
# ids=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
for i,val in enumerate(id_list):
    if len(val)>11:
        id_list[i]=id_list[i][0:11]

# %%
len(id_list)
# Out:
# 642

# %% [markdown]
# ## Get Videos with search "Jose Mourinho Press Conference"

# %%
# ids_pc=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids_pc.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
ids_pc_list=list(ids_pc)
for i,val in enumerate(ids_pc_list):
    if len(val)>11:
        ids_pc_list[i]=ids_pc_list[i][0:11]

# %%
len(ids_pc_list)
# Out:
# 637

# %% [markdown]
# ## Get videos with search "jose mourinho inter milan interview

# %%
# ids_milan=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids_milan.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
ids_milan_list=list(ids_milan)
for i,val in enumerate(ids_milan_list):
    if len(val)>11:
        ids_milan_list[i]=ids_milan_list[i][0:11]

# %%
len(ids_milan_list)
# Out:
# 302

# %% [markdown]
# ## Get videos with search "jose mourinho real madrid interview

# %%
# ids_madrid=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids_madrid.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
ids_rm_list=list(ids_madrid)
for i,val in enumerate(ids_rm_list):
    if len(val)>11:
        ids_rm_list[i]=ids_rm_list[i][0:11]

# %%
len(ids_madrid)
# Out:
# 415

# %% [markdown]
# ## Get videos with search "jose mourinho chelsea interview"

# %%
# ids_chelsea=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids_chelsea.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
ids_chelsea_list=list(ids_chelsea)
for i,val in enumerate(ids_chelsea_list):
    if len(val)>11:
        ids_chelsea_list[i]=ids_chelsea_list[i][0:11]

# %%
len(ids_chelsea)
# Out:
# 399

# %% [markdown]
# ## Get videos with search "jose mourinho manchester united interview"

# %%
# ids_manu=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids_manu.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
ids_manu_list=list(ids_manu)
for i,val in enumerate(ids_manu_list):
    if len(val)>11:
        ids_manu_list[i]=ids_manu_list[i][0:11]

# %%
len(ids_manu_list)
# Out:
# 458

# %% [markdown]
# ## Get videos with search "jose mourinho manchester united press conference"

# %%
# ids_manupc=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids_manupc.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
ids_manupc_list=list(ids_manupc)
for i,val in enumerate(ids_manupc_list):
    if len(val)>11:
        ids_manupc_list[i]=ids_manupc_list[i][0:11]

# %%
len(ids_manupc_list)
# Out:
# 579

# %% [markdown]
# ## Get videos with search "jose mourinho chelsea press conference"

# %%
# ids_chelpc=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids_chelpc.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
ids_chelpc_list=list(ids_chelpc)
for i,val in enumerate(ids_chelpc_list):
    if len(val)>11:
        ids_chelpc_list[i]=ids_chelpc_list[i][0:11]

# %%
len(ids_chelpc_list)
# Out:
# 460

# %% [markdown]
# ## Get videos with search "jose mourinho real madrid press conference"

# %%
# ids_rmpc=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids_rmpc.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
ids_rmpc_list=list(ids_rmpc)
for i,val in enumerate(ids_rmpc_list):
    if len(val)>11:
        ids_rmpc_list[i]=ids_rmpc_list[i][0:11]

# %%
len(ids_rmpc_list)
# Out:
# 340

# %% [markdown]
# ## Get videos with search "jose mourinho inter milan press conference"

# %%
# ids_impc=set([])

# for window in range(0,1000000,500): 
#     elems = driver.find_elements_by_xpath("//a[@href]")
#     for elem in elems:
#         if '/watch?' in str(elem.get_attribute("href")):
#             ids_impc.add(str(elem.get_attribute("href")).split('=')[1])
#     driver.execute_script("window.scrollTo(0,"+str(window)+")")

# %%
ids_impc_list=list(ids_impc)
for i,val in enumerate(ids_impc_list):
    if len(val)>11:
        ids_impc_list[i]=ids_impc_list[i][0:11]

# %%
len(ids_impc_list)
# Out:
# 223

# %% [markdown]
# ## Put all ids together and export

# %%
final_set=set(ids_pc_list+id_list+ids_milan_list+ids_rm_list+ids_chelsea_list+
             ids_manu_list+ids_manupc_list+ids_chelpc_list+ids_rmpc_list+ids_impc_list)

# %%
len(final_set)
# Out:
# 2236

# %%
import pickle

filename = 'Data/youtube_ids.pkl'
pickle.dump(final_set, open(filename, 'wb'))

# %%
final_set
# Out:
# {'7BHU9BJFsmw',
#  'EDHrne1wblE',
#  'hASjWG0mQy4',
#  'cgXqyvy_q6g',
#  'AhwVE58d-zg',
#  'tzzA9rZl17I',
#  'pKxM0QGJOlU',
#  'FdK8v0gZVUQ',
#  'CHggMe62QXY',
#  'lphVAowYQQI',
#  'yFqz9HWvDKw',
#  '2ZY6APD91tw',
#  'X0RBHSGmLbc',
#  'zm7syOqzT5c',
#  'OqTH5SMCshI',
#  'TAaRs5HFRTw',
#  '4AYD_jV3p20',
#  'XioSlD0X-xY',
#  'cBej-sNxkbc',
#  'aiosMP5YaA8',
#  'Z_913IsemQY',
#  'J-aOMU04kEA',
#  'FkVKtet-15k',
#  'viJHTmFvkpk',
#  'uiCtGPXGi04',
#  'JfxLOyMQ2Do',
#  '0ngMDAnbZio',
#  'UQPFY4EswH4',
#  'ZZ750bUILgs',
#  'iLHlY4YFI6s',
#  'AJdwMenySyM',
#  '0MjE0KpyqoQ',
#  'EV_VQAF9N6g',
#  'GyTUa3x0zkU',
#  'QrxsU5zboVs',
#  '0H96j2_ZvQg',
#  '7uIQRSRArY4',
#  'jeOq-xeSGTA',
#  '1ijcAr0E5ow',
#  'Ya4MoxV-ktw',
#  'H7bK0Lc8iv8',
#  'cRfxXGTvlHU',
#  'v1UfPFX6RcE',
#  'akuIGtvRxow',
#  'ET1Hhp9ixA8',
#  'ebdHcbwytfI',
#  '4n5GWEkrYPA',
#  'Kkhz94ooejg',
#  'wmsoax7xx0s',
#  '874mU7cLjp4',
#  'Jibe3tXDPNk',
#  'WI3_yIFTWHQ',
#  'npfhDfOsRDg',
#  '3qmYs51mYI4',
#  'QWgib1Qve9w',
# ...
